# %% [markdown]
# # VARSHA SHAJAN

# %% [markdown]
# # Sales Prediction

# %% [markdown]
# # Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the dataset

# %%
df=pd.read_csv(r"C:\Users\User\Desktop\Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# # Detailing the dataset

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df.count()
# Out:
# Unnamed: 0    200
# TV            200
# Radio         200
# Newspaper     200
# Sales         200
# dtype: int64

# %%
df.mean()
# Out:
# Unnamed: 0    100.5000
# TV            147.0425
# Radio          23.2640
# Newspaper      30.5540
# Sales          14.0225
# dtype: float64

# %%
df.median()
# Out:
# Unnamed: 0    100.50
# TV            149.75
# Radio          22.90
# Newspaper      25.75
# Sales          12.90
# dtype: float64

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# Radio         0.094175
# Newspaper     0.894720
# Sales         0.407571
# dtype: float64

# %% [markdown]
# The datset contain 200 rows and 5 columns.The function describe gives us the details about the dataset.
#
# Mean, Median and skew of the dataset can also be obtained from the dataset

# %% [markdown]
# # Cleaning the dataset

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no null values and dupliacted values

# %% [markdown]
# # Removing Outliers of the dataset

# %%
columns= [i for i in df]

# %%
columns
# Out:
# ['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales']

# %%
try:
    for i in columns:
        plt.title(i)
        sns.boxplot(data=df[i])
        plt.show()
except:
    print('Categorical variable')

# %% [markdown]
# There is no much noise in the dataset

# %% [markdown]
# # Data Visulaization

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# Pairplot gives us the pictorial representaion of the dataset. It gives us the overall details of the dataset by considering all the columns and how each columns are related to each other.

# %%
sns.displot(data=df)
plt.show()

# %%
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %% [markdown]
# We can find the correlation of the dataset using heatmap. In positive correlation when one attribute increase the other will also increase. In negative correlation when one attribute increase the other will decrease.
#
# Here tv and newspaper, tv and radio are negatively correlated.Tv and sales are positively correlated.

# %% [markdown]
# # Modeling

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['Sales'],axis=1)
y=df['Sales']

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_test
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 116         117  139.2   14.3       25.6
# 67           68  139.3   14.5       10.2
# 78           79    5.4   29.9        9.4
# 42           43  293.6   27.7        1.8
# 17           18  281.4   39.6       55.8
# ..          ...    ...    ...        ...
# 133         134  219.8   33.5       45.1
# 137         138  273.7   28.9       59.7
# 72           73   26.8   33.0       19.3
# 140         141   73.4   17.0       12.9
# 37           38   74.7   49.4       45.7
#
# [140 rows x 4 columns]

# %% [markdown]
# x_train

# %%
y_test
# Out:
# 116    12.2
# 67     13.4
# 78      5.3
# 42     20.7
# 17     24.4
#        ...
# 133    19.6
# 137    20.8
# 72      8.8
# 140    10.9
# 37     14.7
# Name: Sales, Length: 140, dtype: float64

# %% [markdown]
# By splitting the datset 70% is used for training the dataset and remaining 30% is used for testing.

# %% [markdown]
# # Fitting into the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60, 4)
# (140, 4)
# (60,)
# (140,)

# %%
model.score(x_train,y_train)
# Out:
# 0.9411812160537496

# %% [markdown]
# # Predictions

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([11.81489283, 11.99524211,  9.71993717, 21.4829202 , 23.35092097,
#        13.80322388,  6.24605126, 18.66972149, 15.82094779,  9.70533662,
#        20.33753899, 21.26109225, 24.08906509, 11.25773702, 11.77915032,
#        16.24884839, 11.44194027,  6.24591459, 21.21247208, 14.54759372,
#        15.39649533,  9.65042548, 13.80467865, 12.81976669,  8.36386998,
#         8.79047199, 10.44257547,  9.22545872, 17.12642537, 15.18796595,
#        17.59290234, 23.88787389, 14.11662915,  9.05801404, 18.6542461 ,
#        14.56147682,  5.18489689, 12.31038228, 13.28982549, 11.46021723,
#        12.85407088, 14.05848779,  4.32333119, 16.27351739, 13.53358694,
#        17.91844749, 14.83716462, 17.60589934, 12.57256005, 13.71557825,
#        20.74365614,  5.56869799, 14.24934704,  7.93119781, 21.95831103,
#        12.63843144, 11.92873702, 11.59763153,  8.78964216, 16.35966821,
#        17.32273544, 19.21696559, 23.7100257 , 13.98043135,  8.38835295,
# ...

# %% [markdown]
# # Evaluation

# %%
from sklearn import metrics
print("MAR:",metrics.mean_absolute_error(y_pred,y_test))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
print("R-Squared",metrics.r2_score(y_pred,y_test))

# %% [markdown]
# # Predictions on Unknown data

# %%
print(model.predict([[138,236,55,67]]))
# Out:
# [24.62662464]
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # THANK YOU
